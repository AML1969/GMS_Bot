# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.16-py3-none-any.whl (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.4/715.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.16

# %%
# !pip install ultralytics
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

#~ USAGE
# cd c:\my_campy
# .\camenv8\Scripts\activate
# cd c:\my_campy\SafeCity_Voronezh\dataset_preparation
#~~~~~~~~~~~~~~~~~~~~~~~~
#~ !!! в именах директорий, файлов не допускается использовать пробелы и спецсимволы,
#~ так как они передаются через параметры командной строки !!!
#~~~~~~~~~~~~~~~~~~~~~~~~
#~ --src_dir -> директория с входными изображениями для детектирования
#~ --weights_fname -> путь к файлу весов
#~ --classes_fname -> путь к файлу классов
#~ --threshold = 0.5 -> порог детектирования
#~ --dst_dir -> директория с результатами
#~~~~~~~~~~~~~~~~~~~~~~~~
#~ последовательность выполняемых скриптом действий:
#~ 01. удаление dst_dir
#~ 02. детектирование объектов на изображениях и сохранение их в результирующую папку
#~~~~~~~~~~~~~~~~~~~~~~~~
# python step07_yolov8_image_custom_weights_checker.py --src_dir c:/perimeter_raw_dataset6/test/images --weights_fname c:/perimeter_common_weights/best.pt --classes_fname c:/perimeter_common_weights/classes.txt --threshold 0.5 --dst_dir c:/perimeter_custom_check
#~~~~~~~~~~~~~~~~~~~~~~~~


#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~ https://github.com/ultralytics/ultralytics
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~ import the necessary packages
from ultralytics import YOLO
import os
import shutil
import time
import cv2
#~ передача аргументов через командную строку
# import argparse

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def delete_directory(path: str):
  if os.path.exists(path):
    try:
      shutil.rmtree(path)
      # print(f'[INFO] Directory was successfully deleted: `{path}`')
    except OSError as e:
      print(f'[ERROR] Error deleting a directory: `{path}`: {e.strerror}')
      return

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def make_directory(path: str):
  if not os.path.exists(path):
    os.makedirs(path)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def delete_make_directory(path: str):
  delete_directory(path)
  make_directory(path)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def get_base_suffix_fname(file_name: str) -> tuple:
  #~ разделяем имя файла и расширение
  base_fname, suffix_fname = os.path.splitext(file_name)
  return base_fname,suffix_fname

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def get_image_list(src_dir: str):
  img_lst = []
  for fname in os.listdir(src_dir):
    if os.path.isfile(os.path.join(src_dir, fname)):
      if fname.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
        img_lst.append(fname)
  return img_lst

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def check_file_existence(file_path: str) -> bool:
  return os.path.exists(file_path)

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def read_classes(file_name: str):
  classes_lst = []
  if not check_file_existence(file_name):
    # print(f'[WARNING] The file was not found: `{file_name}`')
    return classes_lst
  #~~~~~~~~~~~~~~~~~~~~~~~~
  with open(file_name, 'r', encoding='utf-8') as file:
    classes_lst = [line.strip() for line in file if line.strip()]
  return classes_lst

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def format_execution_time(execution_time):
  if execution_time < 1:
    return f"{execution_time:.3f} sec"

  hours = int(execution_time // 3600)
  minutes = int((execution_time % 3600) // 60)
  seconds = int(execution_time % 60)

  if execution_time < 60:
    return f"{seconds}.{int((execution_time % 1) * 1000):03d} sec"
  elif execution_time < 3600:
    return f"{minutes} min {seconds:02d} sec"
  else:
    return f"{hours} h {minutes:02d} min {seconds:02d} sec"

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def main_step07_yolov8_image_custom_weights_checker(src_dir: str, weights_fname: str, classes_fname: str, threshold: float, dst_dir: str):
  start_time = time.time()
  print('~'*70)
  print('[INFO] Testing the detection of YOLOv8 objects in a custom dataset in images ver.2024.02.20')
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ входные папаметры
  #~~~~~~~~~~~~~~~~~~~~~~~~
  print('~'*70)
  print(f'[INFO] src_dir: `{src_dir}`')
  print(f'[INFO] weights_fname: `{weights_fname}`')
  print(f'[INFO] classes_fname: `{classes_fname}`')
  print(f'[INFO] threshold: `{threshold}`')
  print(f'[INFO] dst_dir: `{dst_dir}`')
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 00. проверяем входную директорию на существование
  #~~~~~~~~~~~~~~~~~~~~~~~~
  if not os.path.exists(src_dir):
    print(f'[ERROR] input folder is not exists: `{src_dir}`')
    return
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 01. удаление dst_dir
  #~~~~~~~~~~~~~~~~~~~~~~~~
  delete_make_directory(dst_dir)
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 02. определение списка поддерживаемых классов из файла classes.txt
  #~~~~~~~~~~~~~~~~~~~~~~~~
  print('~'*70)
  print(f'[INFO] object detection is in progress...')
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 03. определяем 20 различных цветов в формате BGR
  #~~~~~~~~~~~~~~~~~~~~~~~~
  color_lst = [
    (36, 28, 237),   #~ красный
    (39, 127, 255),  #~ оранжевый
    (0, 242, 255),   #~ желтый
    (76, 177, 34),   #~ зеленый
    (232, 162, 0),   #~ голубой
    (204, 72, 63),   #~ синий
    (164, 73, 163),  #~ фиолетовый
    (21, 0, 136),    #~ коричневый
    (127, 127, 127), #~ серый
    (0, 0, 0),       #~ черный
    (201, 174, 255), #~ розовый
    (14, 201, 255),  #~ темно-желтый
    (176, 228, 239), #~ светло-желтый
    (29, 230, 181),  #~ салатовый
    (234, 217, 153), #~ голубой
    (190, 146, 112), #~ темно-синий
    (231, 191, 200), #~ светло-фиолетовый
    (87, 122, 185),  #~ светло-коричневый
    (195, 195, 195), #~ светло-серый
    (255, 255, 255)  #~ белый
  ]
  color_lst_len = len(color_lst)
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 04. список файлов изображений
  #~~~~~~~~~~~~~~~~~~~~~~~~
  class_lst = read_classes(classes_fname)
  class_lst_len = len(class_lst)
  if class_lst_len < 1:
    class_lst_len = 0
  # print(f'[INFO] classes_lst: len: {class_lst_len}, `{class_lst}`')
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 05. список файлов изображений
  #~~~~~~~~~~~~~~~~~~~~~~~~
  img_lst =  get_image_list(src_dir)
  img_lst_len = len(img_lst)
  if img_lst_len < 1:
    print(f'[ERROR] List of images is empty: `{src_dir}`')
    return
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ YOLOv8 model on custom dataset
  #~ load a model
  #~~~~~~~~~~~~~~~~~~~~~~~~
  # model = YOLO('yolov8m.pt')
  model = YOLO(weights_fname)
  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 06. обрабатываем все изображения из входной папки
  #~~~~~~~~~~~~~~~~~~~~~~~~
  for i in range(img_lst_len):
    base_fname,suffix_fname = get_base_suffix_fname(img_lst[i])
    img_fname1 = os.path.join(src_dir, img_lst[i])
    img_fname2 = os.path.join(dst_dir, img_lst[i])
    print('~'*70)
    print(f'[INFO] `{img_lst[i]}`')
    # print(f'[INFO] img_fname1: `{img_fname1}`')
    # print(f'[INFO] img_fname2: `{img_fname2}`')
    #~~~~~~~~~~~~~~~~~~~~~~~~
    image = cv2.imread(img_fname1)
    #~~~~~~~~~~~~~~~~~~~~~~~~
    #~ предсказание модели
    results = model(image)[0]
    for result in results.boxes.data.tolist():
      x1, y1, x2, y2, score, class_id_f = result
      #~~~~~~~~~~~~~~~~~~~~~~~~
      if score < threshold:
        continue
      score_str = str(round(score, 2))
      #~~~~~~~~~~~~~~~~~~~~~~~~
      inxcolor = (255, 255, 255)
      class_id = int(class_id_f)
      obj_label = str(class_id)
      if 0 <= class_id and class_id < color_lst_len:
        inxcolor = color_lst[class_id]
      if 0 <= class_id and class_id < class_lst_len:
        obj_label = f'{class_id} {class_lst[class_id]}'
      x_min = int(x1)
      y_min = int(y1)
      x_max = int(x2)
      y_max = int(y2)
      #~~~~~~~~~~~~~~~~~~~~~~~~
      cv2.rectangle(image, (x_min, y_min), (x_max, y_max), inxcolor, 2)
      #~ добавляем подпись класса объекта
      cv2.putText(image, obj_label, (x_min+3, y_min+15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, inxcolor, 3)
      cv2.putText(image, obj_label, (x_min+3, y_min+15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
      #~~~~~~~~~~~~~~~~~~~~~~~~
      cv2.imwrite(img_fname2, image)

  #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
  #~ 07. вычисляем время выполнения
  #~~~~~~~~~~~~~~~~~~~~~~~~
  execution_time = time.time() - start_time
  execution_time_str = format_execution_time(execution_time)
  print('='*70)
  print(f'[INFO] program execution time: {execution_time_str}')
  print('='*70)

# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# if __name__ == "__main__":
#   parser = argparse.ArgumentParser(description='Testing the detection of YOLOv8 objects in a custom dataset in images.')
#   parser.add_argument('--src_dir', type=str, default='', help='Directory with input data')
#   parser.add_argument('--weights_fname', type=str, default='', help='Path to the weights file')
#   parser.add_argument('--classes_fname', type=str, default='', help='Path to the classes file')
#   parser.add_argument('--threshold', type=float, default=0.5, help='Proportional compression of the frame in width and height')
#   parser.add_argument('--dst_dir', type=str, default='', help='Directory with results')
#   args = parser.parse_args()
#   #~~~~~~~~~~~~~~~~~~~~~~~~
#   main_step07_yolov8_image_custom_weights_checker(args.src_dir, args.weights_fname, args.classes_fname, args.threshold, args.dst_dir)

# %%
#~ подключаем Google Drive
from google.colab import drive
drive.mount('/content/drive')
print('Google Drive подключен!')
# Out:
# Mounted at /content/drive
# Google Drive подключен!

# %%
args_src_dir = '/content/drive/MyDrive/safe_city_step_by_step/test09'
args_weights_fname = '/content/drive/MyDrive/safe_city_step_by_step/best.pt'
args_classes_fname = '/content/drive/MyDrive/safe_city_step_by_step/classes.txt'
args_threshold = 0.5
args_dst_dir = '/content/drive/MyDrive/safe_city_step_by_step/test09-custom'

# %%
main_step07_yolov8_image_custom_weights_checker(args_src_dir, args_weights_fname, args_classes_fname, args_threshold, args_dst_dir)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] Testing the detection of YOLOv8 objects in a custom dataset in images ver.2024.02.20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] src_dir: `/content/drive/MyDrive/safe_city_step_by_step/test09`
# [INFO] weights_fname: `/content/drive/MyDrive/safe_city_step_by_step/best.pt`
# [INFO] classes_fname: `/content/drive/MyDrive/safe_city_step_by_step/classes.txt`
# [INFO] threshold: `0.5`
# [INFO] dst_dir: `/content/drive/MyDrive/safe_city_step_by_step/test09-custom`
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] object detection is in progress...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000018-57d12b02-cf3a-11ee-879e-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 76.6ms
# Speed: 20.5ms preprocess, 76.6ms inference, 642.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0
bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 38.8ms
# Speed: 5.9ms preprocess, 38.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000036-580c926e-cf3a-11ee-9cf2-bcee7b784ecb.jpg`
#
# 0: 576x1024 3 weapons, 24.4ms
# Speed: 5.6ms preprocess, 24.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000015-57d067cf-cf3a-11ee-9046-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 39.9ms
# Speed: 7.1ms preprocess, 39.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000009-57c434b4-cf3a-11ee-bbdd-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 24.1ms
# Speed: 5.0ms preprocess, 24.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000003-57c2122d-cf3a-11ee-b264-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 43.6ms
# Speed: 5.6ms preprocess, 43.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000023-5808ad6d-cf3a-11ee-a301-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.6ms
# Speed: 10.8ms preprocess, 39.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000017-57d0dced-cf3a-11ee-9c76-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 24.9ms
# Speed: 5.5ms preprocess, 24.9ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000002-57b1364b-cf3a-11ee-afa2-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 5.7ms preprocess, 40.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000033-580bcf45-cf3a-11ee-8561-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 40.6ms
# Speed: 5.8ms preprocess, 40.6ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000016-57d0b5e2-cf3a-11ee-8426-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 5.9ms preprocess, 40.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000025-58092287-cf3a-11ee-acee-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.5ms
# Speed: 5.8ms preprocess, 41.5ms inference, 2.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000012-57c4d0d4-cf3a-11ee-895f-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 39.9ms
# Speed: 7.7ms preprocess, 39.9ms inference, 3.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000022-58085f5d-cf3a-11ee-8303-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.2ms
# Speed: 6.3ms preprocess, 41.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000026-58094991-cf3a-11ee-aa35-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.4ms
# Speed: 6.5ms preprocess, 40.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000019-57d1520b-cf3a-11ee-ae92-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 23.2ms
# Speed: 7.2ms preprocess, 23.2ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000032-580ba819-cf3a-11ee-8498-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 39.4ms
# Speed: 6.5ms preprocess, 39.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000040-581884db-cf3a-11ee-909b-bcee7b784ecb.jpg`
#
# 0: 768x1024 1 fire, 31.4ms
# Speed: 5.4ms preprocess, 31.4ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000028-5809beb4-cf3a-11ee-b0d2-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.0ms
# Speed: 5.7ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000121-58918acf-cf3a-11ee-b9e0-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.8ms
# Speed: 5.9ms preprocess, 41.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000152-58ae7df2-cf3a-11ee-83fe-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.1ms
# Speed: 5.9ms preprocess, 41.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000128-58a28bc7-cf3a-11ee-957b-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 24.5ms
# Speed: 6.2ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000104-588e086c-cf3a-11ee-83d7-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.5ms
# Speed: 7.2ms preprocess, 39.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000150-58ae084d-cf3a-11ee-8040-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 39.8ms
# Speed: 8.3ms preprocess, 39.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000155-58af1a18-cf3a-11ee-8d91-bcee7b784ecb.jpg`
#
# 0: 576x1024 1
0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000089-588556dd-cf3a-11ee-aaa2-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000100-588cd0a1-cf3a-11ee-94f1-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.3ms
# Speed: 5.7ms preprocess, 41.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000149-58ad8d0c-cf3a-11ee-a271-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 fires, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000151-58ae2f54-cf3a-11ee-9b1c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.4ms
# Speed: 6.6ms preprocess, 41.4ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000130-58a48748-cf3a-11ee-98b3-bcee7b784ecb.jpg`
#
# 0: 576x1024 4 weapons, 24.2ms
# Speed: 8.4ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000059-58478f80-cf3a-11ee-aab4-bcee7b784ecb.jpg`
#
# 0: 640x1024 1 fire, 74.6ms
# Speed: 4.3ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000099-588c347a-cf3a-11ee-8275-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.5ms
# Speed: 6.1ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000131-58a522e7-cf3a-11ee-9b6b-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.0ms
# Speed: 7.5ms preprocess, 41.0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000048-583f441e-cf3a-11ee-adbb-bcee7b784ecb.jpg`
#
# 0: 1024x1024 4 fires, 41.3ms
# Speed: 6.5ms preprocess, 41.3ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000095-588a3823-cf3a-11ee-a05a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.3ms
# Speed: 6.6ms preprocess, 41.3ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000111-588f675f-cf3a-11ee-92f0-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.4ms
# Speed: 6.5ms preprocess, 41.4ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000101-588d44e7-cf3a-11ee-8502-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 24.9ms
# Speed: 6.1ms preprocess, 24.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000129-58a375fb-cf3a-11ee-8903-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 42.1ms
# Speed: 7.6ms preprocess, 42.1ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000162-58bf5054-cf3a-11ee-b27a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 7 fires, 41.5ms
# Speed: 6.7ms preprocess, 41.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000065-584d2923-cf3a-11ee-9c65-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.8ms
# Speed: 5.2ms preprocess, 41.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000088-58844593-cf3a-11ee-9260-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.2ms
# Speed: 8.6ms preprocess, 40.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000164-58c0ae52-cf3a-11ee-ab89-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 41.9ms
# Speed: 7.6ms preprocess, 41.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000132-58a5bf10-cf3a-11ee-b319-bcee7b784ecb.jpg`
#
# 0: 1024x1024 (no detections), 38.5ms
# Speed: 7.4ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000145-58aa9fdb-cf3a-11ee-9e87-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 43.0ms
# Speed: 5.7ms preprocess, 43.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000147-58aaedec-cf3a-11ee-9f0c-bcee7b784ecb.jpg`
#
# 0: 1024x704 (no detections), 73.8ms
# Speed: 5.2ms preprocess, 73.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 704)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000077-586d3cff-cf3a-11ee-b96f-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 40.8ms
# Speed: 6.8ms preprocess, 40.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000118-5890edc3-cf3a-11ee-bd32-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 23.9ms
# Speed: 5.3ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000093-588926dd-cf3a-11ee-a280-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 weapons, 43.4ms
# Speed: 8.4ms preprocess, 43.4ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0
0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000166-58c1e77e-cf3a-11ee-bcb2-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.0ms
# Speed: 5.5ms preprocess, 24.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000144-58aa51c7-cf3a-11ee-8152-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 23.3ms
# Speed: 6.3ms preprocess, 23.3ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000042-581a8056-cf3a-11ee-8c7e-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 24.1ms
# Speed: 3.9ms preprocess, 24.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000096-588aae12-cf3a-11ee-baa4-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.0ms
# Speed: 6.6ms preprocess, 41.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000055-5846091b-cf3a-11ee-9c5e-bcee7b784ecb.jpg`
#
# 0: 1024x640 1 fire, 79.2ms
# Speed: 5.0ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 640)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000161-58be661e-cf3a-11ee-a4b8-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.1ms
# Speed: 6.3ms preprocess, 39.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000158-58bb30dd-cf3a-11ee-bfda-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 23.0ms
# Speed: 6.8ms preprocess, 23.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000053-58416691-cf3a-11ee-860f-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 22.3ms
# Speed: 5.8ms preprocess, 22.3ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000052-5840f175-cf3a-11ee-8857-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 33.1ms
# Speed: 6.5ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000148-58ad3e5a-cf3a-11ee-884a-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 47.5ms
# Speed: 6.7ms preprocess, 47.5ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000109-588f194a-cf3a-11ee-9c51-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 79.5ms
# Speed: 5.9ms preprocess, 79.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000063-5848eed8-cf3a-11ee-8d23-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 47.9ms
# Speed: 6.2ms preprocess, 47.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000056-5846572f-cf3a-11ee-9075-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 47.4ms
# Speed: 6.5ms preprocess, 47.4ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000074-584f72ce-cf3a-11ee-b1d7-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 77.3ms
# Speed: 7.6ms preprocess, 77.3ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000174-58c5901f-cf3a-11ee-a498-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 69.6ms
# Speed: 9.5ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000108-588ecb36-cf3a-11ee-b671-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 45.0ms
# Speed: 5.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000071-584eaf9a-cf3a-11ee-8f53-bcee7b784ecb.jpg`
#
# 0: 1024x736 1 fire, 71.7ms
# Speed: 5.1ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 736)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000098-588bbf5d-cf3a-11ee-9b24-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 43.6ms
# Speed: 7.8ms preprocess, 43.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000177-58c6534b-cf3a-11ee-b51c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 42.8ms
# Speed: 6.2ms preprocess, 42.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000165-58c14b58-cf3a-11ee-8949-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 42.4ms
# Speed: 6.9ms preprocess, 42.4ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000050-58402e41-cf3a-11ee-bd0d-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 42.5ms
# Speed: 7.2ms preprocess, 42.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000091-588753c4-cf3a-11ee-a9c4-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 40.9ms
# Speed: 5.7ms preprocess, 40.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000167-58c25ca1-cf3a-11ee-b340-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 40.0ms
# Speed: 5.7ms preprocess, 40.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000154-58aeccb7-cf3a-11ee-a46a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 6.9ms preprocess, 40.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000103-588de162-cf3a-11ee-b94c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.7ms
# Speed: 6.1ms preprocess, 39.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000066-584d774a-cf3a-11ee-8f76-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.5ms
# Speed: 5.8ms preprocess, 41.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000076-586c515f-cf3a-11ee-ac83-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.7ms
# Speed: 5.9ms preprocess, 40.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000160-58bd54da-cf3a-11ee-ba3b-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 26.4ms
# Speed: 5.0ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000106-588e7d22-cf3a-11ee-bb9d-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.1ms
# Speed: 7.2ms preprocess, 40.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000113-588fdc7d-cf3a-11ee-9928-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 40.2ms
# Speed: 6.6ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000083-58726ba5-cf3a-11ee-8130-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 41.9ms
# Speed: 5.6ms preprocess, 41.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000073-584f24bb-cf3a-11ee-9ea5-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 24.6ms
# Speed: 5.1ms preprocess, 24.6ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000110-588f4054-cf3a-11ee-a8f2-bcee7b784ecb.jpg`
#
# 0: 1024x1024 (no detections), 41.0ms
# Speed: 5.6ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000057-5846cc49-cf3a-11ee-90f9-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.5ms
# Speed: 12.3ms preprocess, 40.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000116-589078a6-cf3a-11ee-bc39-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.0ms
# Speed: 6.0ms preprocess, 41.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000142-58a9dcab-cf3a-11ee-937c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.6ms
# Speed: 6.0ms preprocess, 41.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000061-584852b1-cf3a-11ee-bd49-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.8ms
# Speed: 5.5ms preprocess, 41.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000124-589226f9-cf3a-11ee-baf2-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 39.7ms
# Speed: 6.6ms preprocess, 39.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000168-58c2f7ea-cf3a-11ee-82f8-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 23.7ms
# Speed: 4.8ms preprocess, 23.7ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000175-58c5b727-cf3a-11ee-99a5-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 22.9ms
# Speed: 4.8ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000171-58c4a5e3-cf3a-11ee-9aba-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.6ms
# Speed: 5.6ms preprocess, 39.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000049-583fe02c-cf3a-11ee-8617-bcee7b784ecb.jpg`
#
# 0: 1024x1024 4 fires, 41.1ms
# Speed: 9.5ms preprocess, 41.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000051-5840a35e-cf3a-11ee-9de4-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.2ms
# Speed: 8.7ms preprocess, 39.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000156-58af415a-cf3a-11ee-9a0a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.3ms
# Speed: 5.9ms preprocess, 40.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000114-58902a91-cf3a-11ee-b7e8-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.0ms
# Speed: 7.3ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000134-58a6d059-cf3a-11ee-99f5-bcee7b784ecb.jpg`
#
# 0: 736x1024 (no detections), 133.5ms
# Speed: 5.1ms preprocess, 133.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000181-58c78ba0-cf3a-11ee-a8d3-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.3ms
# Speed: 8.3ms preprocess, 40.3ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000080-587022cf-cf3a-11ee-a947-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 23.8ms
# Speed: 5.8ms preprocess, 23.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000170-58c4314d-cf3a-11ee-a626-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 24.9ms
# Speed: 3.4ms preprocess, 24.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000163-58c01210-cf3a-11ee-9945-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 7.9ms preprocess, 40.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000058-58471a58-cf3a-11ee-b305-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 39.4ms
# Speed: 5.9ms preprocess, 39.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000047-583e32d0-cf3a-11ee-9f61-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 39.1ms
# Speed: 7.4ms preprocess, 39.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000069-584e3a7d-cf3a-11ee-a0d3-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 38.8ms
# Speed: 6.3ms preprocess, 38.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000178-58c6a163-cf3a-11ee-abaf-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 40.3ms
# Speed: 6.9ms preprocess, 40.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000090-58864110-cf3a-11ee-993e-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.3ms
# Speed: 5.3ms preprocess, 24.3ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000045-583c3759-cf3a-11ee-bd29-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 22.7ms
# Speed: 7.7ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000143-58aa2aba-cf3a-11ee-b455-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.9ms
# Speed: 10.3ms preprocess, 40.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000068-584dec69-cf3a-11ee-9eb4-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.2ms
# Speed: 9.4ms preprocess, 41.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000135-58a76c7d-cf3a-11ee-8131-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.3ms
# Speed: 8.6ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000046-583d4898-cf3a-11ee-9211-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 40.5ms
# Speed: 8.3ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000169-58c394ea-cf3a-11ee-b433-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 fires, 24.8ms
# Speed: 4.0ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000122-5891d8e2-cf3a-11ee-8eb3-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 23.4ms
# Speed: 4.8ms preprocess, 23.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000067-584d9e54-cf3a-11ee-bbbb-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 22.5ms
# Speed: 5.0ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000189-58d25334-cf3a-11ee-abe6-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.2ms
# Speed: 7.0ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000183-58ced13e-cf3a-11ee-9bf3-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.9ms
# Speed: 8.8ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000208-58d6be56-cf3a-11ee-a054-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 42.6ms
# Speed: 6.6ms preprocess, 42.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000190-58d279cf-cf3a-11ee-be9d-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.6ms
# Speed: 6.2ms preprocess, 40.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000211-58d75a7e-cf3a-11ee-b705-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.6ms
# Speed: 8.8ms preprocess, 41.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000237-58dcffc8-cf3a-11ee-8556-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.7ms
# Speed: 6.3ms preprocess, 40.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000229-58db523d-cf3a-11ee-898e-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 40.4ms
# Speed: 7.7ms preprocess, 40.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000210-58d73373-cf3a-11ee-b758-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 25.8ms
# Speed: 5.7ms preprocess, 25.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000220-58d95604-cf3a-11ee-8c1f-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 39.4ms
# Speed: 6.9ms preprocess, 39.4ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000222-58d9cb21-cf3a-11ee-86fe-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.2ms
# Speed: 6.0ms preprocess, 41.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000209-58d6e560-cf3a-11ee-81a5-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.3ms
# Speed: 5.2ms preprocess, 24.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000188-58d1b706-cf3a-11ee-bcf6-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.7ms
# Speed: 6.6ms preprocess, 40.7ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000204-58d5d419-cf3a-11ee-b30c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 41.8ms
# Speed: 5.7ms preprocess, 41.8ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000184-58cf4664-cf3a-11ee-a4ca-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.4ms
# Speed: 4.7ms preprocess, 24.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000217-58d892cf-cf3a-11ee-a6a3-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.1ms
# Speed: 6.7ms preprocess, 40.1ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000230-58db794a-cf3a-11ee-a36d-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 5.7ms preprocess, 40.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000200-58d4e9dc-cf3a-11ee-8951-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 24.9ms
# Speed: 5.0ms preprocess, 24.9ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000203-58d58606-cf3a-11ee-a961-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 41.5ms
# Speed: 6.2ms preprocess, 41.5ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000186-58d07eb6-cf3a-11ee-8cf9-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 25.3ms
# Speed: 5.5ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000232-58dbee64-cf3a-11ee-849c-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.8ms
# Speed: 5.1ms preprocess, 24.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000198-58d474c0-cf3a-11ee-ba85-bcee7b784ecb.jpg`
#
# 0: 1024x1024 (no detections), 42.6ms
# Speed: 6.8ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000207-58d67042-cf3a-11ee-9750-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 43.0ms
# Speed: 5.8ms preprocess, 43.0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000196-58d40002-cf3a-11ee-823b-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.6ms
# Speed: 6.2ms preprocess, 41.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000185-58cfe28a-cf3a-11ee-ba92-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 24.8ms
# Speed: 6.3ms preprocess, 24.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000202-58d55efc-cf3a-11ee-99cc-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 41.2ms
# Speed: 7.0ms preprocess, 41.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000219-58d92ef1-cf3a-11ee-9550-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 25.0ms
# Speed: 7.4ms preprocess, 25.0ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000195-58d3b1f0-cf3a-11ee-8855-bcee7b784ecb.jpg`
#
# 0: 704x1024 1 fire, 30.0ms
# Speed: 5.0ms preprocess, 30.0ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000226-58dab61a-cf3a-11ee-bac7-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 24.6ms
# Speed: 10.8ms preprocess, 24.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000221-58d9a417-cf3a-11ee-8494-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.0ms
# Speed: 7.7ms preprocess, 41.0ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000235-58dc8a8e-cf3a-11ee-bb1b-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 fire, 24.5ms
# Speed: 4.5ms preprocess, 24.5ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000213-58d7cf9e-cf3a-11ee-85db-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.1ms
# Speed: 6.7ms preprocess, 41.1ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000233-58dc3c81-cf3a-11ee-ae3c-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 25.6ms
# Speed: 7.4ms preprocess, 25.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000193-58d33d04-cf3a-11ee-9d84-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 42.2ms
# Speed: 9.1ms preprocess, 42.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000205-58d5fb23-cf3a-11ee-8b3a-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 weapon, 25.6ms
# Speed: 6.3ms preprocess, 25.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000227-58dadd25-cf3a-11ee-b982-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 42.5ms
# Speed: 7.1ms preprocess, 42.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000212-58d78188-cf3a-11ee-92ac-bcee7b784ecb.jpg`
#
# 0: 1024x1024 3 fires, 41.6ms
# Speed: 5.9ms preprocess, 41.6ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000216-58d86bc5-cf3a-11ee-b8c5-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.7ms
# Speed: 9.1ms preprocess, 41.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000228-58db2b4a-cf3a-11ee-a885-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.4ms
# Speed: 7.2ms preprocess, 41.4ms inference, 3.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000215-58d844ba-cf3a-11ee-a0aa-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 42.9ms
# Speed: 7.8ms preprocess, 42.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000218-58d8e0de-cf3a-11ee-b845-bcee7b784ecb.jpg`
#
# 0: 1024x1024 2 fires, 42.2ms
# Speed: 5.7ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000234-58dc6387-cf3a-11ee-9498-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 26.0ms
# Speed: 5.4ms preprocess, 26.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000192-58d2eeec-cf3a-11ee-a75d-bcee7b784ecb.jpg`
#
# 0: 576x1024 3 weapons, 22.3ms
# Speed: 6.2ms preprocess, 22.3ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000191-58d2c7e6-cf3a-11ee-8386-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 39.1ms
# Speed: 6.0ms preprocess, 39.1ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000231-58dbc75d-cf3a-11ee-b83a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.5ms
# Speed: 8.7ms preprocess, 40.5ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000214-58d7f6a6-cf3a-11ee-a24a-bcee7b784ecb.jpg`
#
# 0: 1024x1024 4 fires, 42.2ms
# Speed: 5.5ms preprocess, 42.2ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000225-58da6804-cf3a-11ee-bb70-bcee7b784ecb.jpg`
#
# 0: 576x1024 2 weapons, 25.4ms
# Speed: 6.7ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000236-58dcd7f1-cf3a-11ee-af93-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 weapon, 41.7ms
# Speed: 8.4ms preprocess, 41.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000199-58d49bc9-cf3a-11ee-a51d-bcee7b784ecb.jpg`
#
# 0: 1024x1024 (no detections), 42.2ms
# Speed: 6.6ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000223-58da1934-cf3a-11ee-912f-bcee7b784ecb.jpg`
#
# 0: 576x1024 (no detections), 25.5ms
# Speed: 5.8ms preprocess, 25.5ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000206-58d64938-cf3a-11ee-815c-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.3ms
# Speed: 5.7ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000194-58d3637e-cf3a-11ee-a639-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 40.8ms
# Speed: 7.0ms preprocess, 40.8ms inference, 1.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000197-58d4270c-cf3a-11ee-a406-bcee7b784ecb.jpg`
#
# 0: 704x1024 (no detections), 35.0ms
# Speed: 4.4ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 704, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000224-58da410d-cf3a-11ee-8784-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.1ms
# Speed: 5.0ms preprocess, 41.1ms inference, 2.4ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000187-58d11ade-cf3a-11ee-bc12-bcee7b784ecb.jpg`
#
# 0: 1024x1024 1 fire, 41.5ms
# Speed: 5.5ms preprocess, 41.5ms inference, 3.2ms postprocess per image at shape (1, 3, 1024, 1024)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [INFO] `f0000201-58d510e7-cf3a-11ee-9e93-bcee7b784ecb.jpg`
#
# 0: 576x1024 1 fire, 25.9ms
# Speed: 4.4ms preprocess, 25.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
# ======================================================================
# [INFO] program execution time: 41.448 sec
# ======================================================================
